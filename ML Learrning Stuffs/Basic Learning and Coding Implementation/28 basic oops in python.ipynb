# %% [markdown]
# 1. Classes and Objects:
# In Python, classes are used to create objects, which are instances of a class. Classes define the blueprint for creating objects, and objects are instances of a class. Here's a simple

# %%
class Dog:
    def __init__(self, name, breed):
        self.name = name
        self.breed = breed

    def bark(self):
        return "Woof!"

# Creating instances (objects) of the Dog class
dog1 = Dog("Buddy", "Golden Retriever")
dog2 = Dog("Rex", "German Shepherd")

# Accessing object attributes and methods
print(dog1.name)  # Output: Buddy
print(dog2.bark())  # Output: Woof!

# In this example, we defined a Dog class with an __init__ constructor method
# and a bark method. We created two Dog objects, dog1 and dog2, and accessed their attributes and methods.
# Out:
# Buddy
# Woof!

# %% [markdown]
#  Q.  what is this self. You are defining function to take 3 parameters but giving only 2, and the object name is working as self ??

# %% [markdown]
# In Python, self is a convention (though not a keyword) that is commonly used as the first parameter in instance methods of a class. It represents the instance of the class itself and allows you to access the instance's attributes and call its methods.
#
# In the __init__ method of the Dog class, self refers to the instance of the Dog class being created. When you create an instance of the class, like dog1 = Dog("Buddy", "Golden Retriever"), Python automatically passes the instance as the first argument, and you don't need to provide it explicitly. self is passed by default as "dog1"
#
# So, self is not something you pass when you call the method; it's automatically provided by Python to refer to the instance. In the __init__ method, it's used to set the attributes name and breed of the instance.
#
# Instance of classs = object of class [ instance = object]

# %% [markdown]
# 2. Inheritance:
# Inheritance allows you to create a new class that inherits properties and methods from an existing class. Here's an example:

# %%
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        pass

class Dog(Animal):
    def speak(self):
        return "Woof!"

class Cat(Animal):
    def speak(self):
        return "Meow!"

dog = Dog("Buddy") # dog class is called
cat = Cat("Whiskers") # cat class is called

print(dog.speak())  # Output: Woof!
print(cat.speak())  # Output: Meow!

# In this example, we have a base class Animal with a speak method, and two subclasses, Dog and Cat, that inherit from Animal and override the speak method.
# Out:
# Woof!
# Meow!

# %% [markdown]
# 3. Encapsulation:
# Encapsulation is the concept of restricting access to certain parts of an object. In Python, you can use private attributes and methods with a leading underscore to indicate that they are intended for internal use. Example:

# %%
class Circle:
    def __init__(self, radius):
        self._radius = radius  # Private attribute

    def _calculate_area(self):  # Private method
        return 3.14 * self._radius * self._radius

    def get_area(self):
        return self._calculate_area()

circle = Circle(5)
print(circle._radius)  # Accessing a private attribute (not recommended)
print(circle.get_area())  # Accessing a private method through a public method

# In this example, _radius and _calculate_area are marked as private, but you can still access them if needed.
# Out:
# 5
# 78.5
