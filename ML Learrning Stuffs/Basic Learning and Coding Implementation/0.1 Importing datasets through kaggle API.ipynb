# %% [markdown]
# ##  API : APPLICATION PROGRAMMING INTERFACE

# %% [markdown]
# # Import datasets directly from kaggle api : helpful for bigger datasets, bina download kiye use krne ka tarika

# %%
# installing the kaggle library
# !pip install kaggle

# %%
#

# %% [markdown]
# Mail id for colab and kaggle should be same

# %% [markdown]
# Upload your kaggle.json file

# %%
# Configuring the path of kaggle.json file
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# API to fetch the dataset
# after accepting competion, or late submission, you have to run the folllowing command 100mb/ps se dataset will be loaded. Mobile data/wifi use nhi hoga
# !kaggle competitions download -c LANL-Earthquake-Prediction
# Out:
# 403 - Forbidden - You must accept this competition's rules before you'll be able to download files.
