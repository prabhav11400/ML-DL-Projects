# %% [markdown]
# ## Dataframe related functions

# %%
import pandas as pd

# %%
# creating pandas dataframe

# %%
# importing the boston house pricing data
# from sklearn.datasets import load_boston

# %%
from sklearn.datasets import fetch_california_housing

# %%
boston_dataset = fetch_california_housing() # vhi name yha rkhna hai jo import ke bad hai

# %%
type(boston_dataset)
# Out:
# sklearn.utils._bunch.Bunch

# %%
print(boston_dataset) # assume boston, callifornia ka hai. and different hai kafi
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
# ...

# %%
boston_df=pd.DataFrame(boston_dataset.data, columns=boston_dataset.feature_names)

# %%
boston_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
boston_df.shape # original me 506,13 thi
# Out:
# (20640, 8)

# %%
# importing data from csv file to dandas dataframe : uplead that dataset in colab directory on drive first

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
diabetes_df=pd.read_csv('/content/diabetes.csv')

# %%
type(diabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetes_df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# loading data from xlsx
# pd.read_excel('content/file.xlsx') # assuming file is present in colab notebook folder in the drive

# %%
boston_df.to_csv('boston.csv')

# %%
# to excel
# df.to_excel(filename)

# %%
import numpy as np
import pandas as pd

# %%
random_df=pd.DataFrame(np.random.rand(20,10)) # 20*10 ki matrix bana dega
# random.rand() all the values between 0 and 1 only

# %%
random_df
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.177260  0.493234  0.835713  0.218431  0.304899  0.259282  0.601278
# 1   0.848063  0.360921  0.854791  0.639345  0.676348  0.158888  0.787929
# 2   0.541333  0.363972  0.950974  0.733071  0.569938  0.488247  0.482544
# 3   0.310707  0.840112  0.436064  0.696165  0.802623  0.984309  0.366875
# 4   0.480762  0.471246  0.243957  0.643614  0.392647  0.093718  0.281338
# 5   0.708154  0.951003  0.798744  0.533316  0.190027  0.853911  0.629794
# 6   0.142177  0.172594  0.574645  0.521453  0.418079  0.064907  0.963198
# 7   0.046787  0.751181  0.907945  0.961211  0.903937  0.663202  0.005614
# 8   0.435815  0.436526  0.898152  0.725669  0.887293  0.198270  0.603502
# 9   0.270766  0.405316  0.032282  0.111850  0.157238  0.461989  0.587151
# 10  0.980054  0.273666  0.489655  0.911589  0.305078  0.216117  0.967477
# 11  0.699778  0.065698  0.346747  0.736862  0.789315  0.570423  0.333009
# ...

# %%
random_df.shape
# Out:
# (20, 10)

# %%
#  finding the number of rows and columns

# %%
boston_df.shape
# Out:
# (20640, 8)

# %%
# first 10 rows in dataframe
boston_df.head(10)
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5  4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
# 6  3.6591      52.0  4.931907   0.951362      1094.0  2.128405     37.84
# 7  3.1200      52.0  4.797527   1.061824      1157.0  1.788253     37.84
# 8  2.0804      42.0  4.294118   1.117647      1206.0  2.026891     37.84
# 9  3.6912      52.0  4.970588   0.990196      1551.0  2.172269     37.84
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25
# 5    -122.25
# 6    -122.25
# 7    -122.25
# 8    -122.26
# 9    -122.25

# %%
boston_df.tail(6) # only tain = last 5 rows
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 20634  3.7125      28.0  6.779070   1.148256      1041.0  3.026163     39.27
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 20634    -121.56
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24

# %%
# information about the dataframe
boston_df.info() # non-null_count = number of non-missing values in a column, ideally should be equal to total row count
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
# dtypes: float64(8)
# memory usage: 1.3 MB

# %%
# to find number of missing values
boston_df.isnull()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0       False     False     False      False       False     False     False
# 1       False     False     False      False       False     False     False
# 2       False     False     False      False       False     False     False
# 3       False     False     False      False       False     False     False
# 4       False     False     False      False       False     False     False
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635   False     False     False      False       False     False     False
# 20636   False     False     False      False       False     False     False
# 20637   False     False     False      False       False     False     False
# 20638   False     False     False      False       False     False     False
# 20639   False     False     False      False       False     False     False
#
#        Longitude
# 0          False
# ...

# %%
boston_df.isnull().sum() # will give number of missing values in each columns
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# dtype: int64

# %%
diabetes_df=pd.read_csv('/content/diabetes.csv')

# %%
# counting values based on labels
diabetes_df.value_counts('Outcome') # count specific values in a column
# Out:
# Outcome
# 0    500
# 1    268
# dtype: int64

# %%
diabetes_df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# # Statistical measures

# %%
# number of values count
boston_df.count()
# Out:
# MedInc        20640
# HouseAge      20640
# AveRooms      20640
# AveBedrms     20640
# Population    20640
# AveOccup      20640
# Latitude      20640
# Longitude     20640
# dtype: int64

# %%
# mean value column wise
boston_df.mean()
# Out:
# MedInc           3.870671
# HouseAge        28.639486
# AveRooms         5.429000
# AveBedrms        1.096675
# Population    1425.476744
# AveOccup         3.070655
# Latitude        35.631861
# Longitude     -119.569704
# dtype: float64

# %%
# standard deviation
boston_df.std()
# Out:
# MedInc           1.899822
# HouseAge        12.585558
# AveRooms         2.474173
# AveBedrms        0.473911
# Population    1132.462122
# AveOccup        10.386050
# Latitude         2.135952
# Longitude        2.003532
# dtype: float64

# %%
boston_df.min()# min max values in each column
boston_df.max()
# Out:
# MedInc          0.499900
# HouseAge        1.000000
# AveRooms        0.846154
# AveBedrms       0.333333
# Population      3.000000
# AveOccup        0.692308
# Latitude       32.540000
# Longitude    -124.350000
# dtype: float64

# %%
boston_df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# ...

# %%
# manipulating a column to DataFrame
boston_df['Price']=boston_dataset.target

# %%
boston_df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Price
# ...

# %%
# removing a particular row
boston_df.drop(index=0, axis=0) # first row is removed
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5      4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Price
# ...

# %%
# drop a column
boston_df.drop(columns='Population',axis=1)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  AveOccup  Latitude  Longitude  \
# 0      8.3252      41.0  6.984127   1.023810  2.555556     37.88    -122.23
# 1      8.3014      21.0  6.238137   0.971880  2.109842     37.86    -122.22
# 2      7.2574      52.0  8.288136   1.073446  2.802260     37.85    -122.24
# 3      5.6431      52.0  5.817352   1.073059  2.547945     37.85    -122.25
# 4      3.8462      52.0  6.281853   1.081081  2.181467     37.85    -122.25
# ...       ...       ...       ...        ...       ...       ...        ...
# 20635  1.5603      25.0  5.045455   1.133333  2.560606     39.48    -121.09
# 20636  2.5568      18.0  6.114035   1.315789  3.122807     39.49    -121.21
# 20637  1.7000      17.0  5.205543   1.120092  2.325635     39.43    -121.22
# 20638  1.8672      18.0  5.329513   1.171920  2.123209     39.43    -121.32
# 20639  2.3886      16.0  5.254717   1.162264  2.616981     39.37    -121.24
#
#        Price
# 0      4.526
# 1      3.585
# ...

# %%
# locating a row using the index value
boston_df.iloc[2] # index =2 ki row column m*2 column ke form me aayegi
# in each operations, to remove permanently , same dataframe = name karo
# Out:
# MedInc          7.257400
# HouseAge       52.000000
# AveRooms        8.288136
# AveBedrms       1.073446
# Population    496.000000
# AveOccup        2.802260
# Latitude       37.850000
# Longitude    -122.240000
# Price           3.521000
# Name: 2, dtype: float64

# %%
print(boston_df.iloc[:,0]) # 1st column pahle
print(boston_df.iloc[:,1]) # 1st ke bad 2nd column pura
print(boston_df.iloc[:,2]) # 1,2 ke bad 3rd column pura
# Out:
# 0        8.3252
# 1        8.3014
# 2        7.2574
# 3        5.6431
# 4        3.8462
#           ...
# 20635    1.5603
# 20636    2.5568
# 20637    1.7000
# 20638    1.8672
# 20639    2.3886
# Name: MedInc, Length: 20640, dtype: float64
# 0        41.0
# 1        21.0
# 2        52.0
# 3        52.0
# 4        52.0
#          ...
# 20635    25.0
# 20636    18.0
# 20637    17.0
# 20638    18.0
# 20639    16.0
# Name: HouseAge, Length: 20640, dtype: float64
# 0        6.984127
# 1        6.238137
# 2        8.288136
# 3        5.817352
# 4        6.281853
#            ...
# 20635    5.045455
# 20636    6.114035
# 20637    5.205543
# 20638    5.329513
# 20639    5.254717
# Name: AveRooms, Length: 20640, dtype: float64

# %%
# correlation among different columns(independent variables, we say roughly); each pair

# %%
boston_df.corr() # by default pearson
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# Price       0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude     Price
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# AveBedrms   0.069721   0.013344 -0.046701
# ...

# %%
boston_df.corr(method="spearman")
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.147308  0.643671  -0.252426    0.006268 -0.044171
# HouseAge   -0.147308  1.000000 -0.231409  -0.120981   -0.283879 -0.024833
# AveRooms    0.643671 -0.231409  1.000000   0.082046   -0.105385  0.018807
# AveBedrms  -0.252426 -0.120981  0.082046   1.000000    0.027027 -0.132315
# Population  0.006268 -0.283879 -0.105385   0.027027    1.000000  0.242337
# AveOccup   -0.044171 -0.024833  0.018807  -0.132315    0.242337  1.000000
# Latitude   -0.088029  0.032440  0.127134   0.047197   -0.123626 -0.150954
# Longitude  -0.009928 -0.150752 -0.044783   0.010884    0.123527  0.181468
# Price       0.676778  0.074855  0.263367  -0.125187    0.003839 -0.256594
#
#             Latitude  Longitude     Price
# MedInc     -0.088029  -0.009928  0.676778
# HouseAge    0.032440  -0.150752  0.074855
# AveRooms    0.127134  -0.044783  0.263367
# AveBedrms   0.047197   0.010884 -0.125187
# ...
