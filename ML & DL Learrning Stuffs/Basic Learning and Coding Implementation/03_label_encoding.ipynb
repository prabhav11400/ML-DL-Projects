# %% [markdown]
# Label Encoding
#
#
# *   Converting the labels into numeric form

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
# loading the data from csv to panda
cancer_data=pd.read_csv("/content/data.csv")
# data.csv is nothing but 'breast_cancer_dataset' only

# %%
cancer_data.head() # features= parameters for cancer cells
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# finding the count of different labels
cancer_data['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
# converting M, B to numeric. As analysing numerical is easier than Characters

# %%
#Loading the label encoder function
label_encode=LabelEncoder()

# %%
labels=label_encode.fit_transform(cancer_data.diagnosis)

# %%
# appending the labels to the dataframe
cancer_data['target']=labels

# %%
cancer_data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
cancer_data['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
cancer_data['target'].value_counts()
# Out:
# 0    357
# 1    212
# Name: target, dtype: int64

# %%
# from the above two codes it is clear that 0 = B, 1 = M
# kon sa label (A,B,C..) ko kon si value(0,1,2,...) milegi
# this is decided by Arranging the labels A,B,C,.. in increasing or alphabetical order. So A =0, B=1, C=3; if Labels A, B C teeno present hon

# %%
# La

# %% [markdown]
# Label Encoding of the iris data
# This has total 3 specias(labels)

# %%
iris_data=pd.read_csv("/content/iris_data.csv")

# %%
iris_data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_data.shape
# Out:
# (150, 6)

# %%
iris_data['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
label_encoder_1=LabelEncoder() # name label encoder bhi chal jata, just pichle vale name se differet krne ke liye ea liya _1.

# %%
iris_labels=label_encoder_1.fit_transform(iris_data.Species)

# %%
iris_data['target']=iris_labels

# %%
iris_data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
print(iris_data['Species'].value_counts())
print(iris_data['target'].value_counts())
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64
# 0    50
# 1    50
# 2    50
# Name: target, dtype: int64

# %%
# labels in 0,1,2 : alphabeticLLY as per species names
