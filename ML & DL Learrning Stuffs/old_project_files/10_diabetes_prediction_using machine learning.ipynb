# %%
# !pip install -U scikit-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 27.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ...

# %% [markdown]
# # classification project : Binary : person is diabetic or not

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
# data collection and analysis
# data is only of females, as pregnensies is mentioned

# %%
diabetes_dataset=pd.read_csv('/content/diabetes.csv') # headers are available, so headers=NaN krke,0,1,2.. as headers we won't need

# %%
diabetes_dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_dataset.shape
# Out:
# (768, 9)

# %%
diabetes_dataset.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
diabetes_dataset.isnull().sum().sum()
# Out:
# 0

# %%
# getting the statistical measures of the data
diabetes_dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
diabetes_dataset['Outcome'].value_counts()
# 0 - nondiabetic, 1- diabetic
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
diabetes_dataset.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
#Separating data and label
X=diabetes_dataset.drop(columns='Outcome', axis=1)
# X will be everything(features) except the outcome(label) column
Y=diabetes_dataset['Outcome']

# %%
print(X)
print("*******************************************")
print(Y)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
#Standardizing the data : taki for all features, range same ho jaye

# %%
scaler=StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %% [markdown]
# The code scaler.fit(X) computes the mean and standard deviation of the features in the dataset X. These values are used to standardize the data, ensuring all features have a similar scale, which is important for many machine learning algorithms to work effectively.

# %%
standardized_data=scaler.transform(X)

# %%
print(standardized_data)
# here in standardized data, all the features will have mean ~0 and variance ~1. But range is not bounded.
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
X=standardized_data
Y=diabetes_dataset['Outcome']

# %%
print(X)
print(Y)
# these are actual X(features) and labels(Y) that we are gonna use for further analysis, this is standardized for ML Model simplicity
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
# here we have chose the approach : " standardized all and then split "

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, x_train.shape, x_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %% [markdown]
# ## Training the moddel using svc:support vector classifier

# %%
classifier=svm.SVC(kernel='linear')

# %%
# training the support vector machine classifier
classifier.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# # modal evaluation : accuracy score

# %%
x_train_prediction=classifier.predict(x_train)
training_data_accuracy=accuracy_score(x_train_prediction, y_train)

# %%
print("Accuracy score of the training data : ", training_data_accuracy)
# Out:
# Accuracy score of the training data :  0.7866449511400652

# %%
# > 70 is good, but wait it was checking accuracy on training data

# %%
# accuray prediction on test data
x_test_prediction = classifier.predict(x_test)
test_data_accuracy=accuracy_score(x_test_prediction, y_test)
print(test_data_accuracy)
# Out:
# 0.7727272727272727

# %%
# prety good, by SVM, also shows that the model is not overfitted, overfitting=
# high accuracy in training data prediction
# low accuracy in test data prediction

# %% [markdown]
# making a predictive system for input data

# %%
input_data=(1,85,66,29,0,26.6,0.351,31)
# changing input data to a numpy array
input_data_as_numpy_array=np.asarray(input_data)
# reshape the array as we are predicting for one instance : ml required 2D matrix as input
# reshaping will tell the array we just need one datapoint
input_data_reshaped=input_data_as_numpy_array.reshape(1,-1)

# since X test be stardized use kiya gya, so we need to standardize input data first before using as unknown test data
std_data=scaler.transform(input_data_reshaped)
print(std_data)

prediction=classifier.predict(std_data)
print(prediction)
# Out:
# [[-0.84488505 -1.12339636 -0.16054575  0.53090156 -0.69289057 -0.68442195
#   -0.36506078 -0.19067191]]
# [0]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
# so we get the expected as 1, person is diabetic
# output is numpy array consisting of only 1 element
# error showing that features headers nhi diye, training k time pr ve diye gye the. Don't worry for that

# %%
# more beautification :
if(prediction[0]==0):
  print("The person is not diabetic")
else:
  print("The person is diabetic")
# Out:
# The person is not diabetic

# %% [markdown]
# # saving the trained model

# %%
import pickle

# %%
filename = 'trained_model.sav' # iss file me model save kro
pickle.dump(classifier,open(filename,'wb')) # write the model in wb = binary formate

# %%
# loading the saved model

# %%
loaded_model = pickle.load(open('/content/trained_model.sav','rb'))

# %%
# standardization part is missing right now. Bad me smjhna. Accuracy almost equal hi aa rhi thi
